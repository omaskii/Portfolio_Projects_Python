# %% [markdown]
# # Solomon Akatakpo (Ph.D.)
#
# # **Monkey Species Classification**
#
#
#
# ### **Context:**
# Several species of monkeys have become extinct in recent years. As a result, a wildlife sanctuary in the United States has taken an important step forward in gathering data on all species that are currently endangered. They have collected images of monkeys from several continents. However, it has become difficult for them to organize all of these images into their respective categories. They require a solution to identify these images into their relevant monkey species groups. As a data scientist, you have to create an efficient model to classify these images into their respective categories.
#
# ### **Objective:**
#
# Building a Convolutional Neural Network model to classify the monkey species into their respective categories.
#
# ### **Data Description:**
#
# This dataset is taken from Kaggle and it consists of the various species of monkeys.
# -  Due to the large volume of data, the images were converted to the images.npy file and the labels are also placed in Labels.csv, allowing you to work on the data without being concerned about the large data volume.
# - The dataset comprises of 10 monkey species.
#
# **List of Species**
# - Mantled Howler
# - Patas Monkey
# - Bald Monkey
# - Japanese Macaque
# - Pygmy Marmoset
# - White Headed Capuchin
# - Silver Marmosetr
# - Common Squirrel Monkey
# - Black Headed Night Monkey
# - Nilgiri Langur
#
#
#
# ####**Note: I have used GPU runtime to execute the code efficiently**

# %% [markdown]
# ## **Importing the necessary libraries**

# %%
import os
import numpy as np                                                                               # Importing numpy for Matrix Operations
import pandas as pd                                                                              # Importing pandas to read CSV files
import matplotlib.pyplot as plt                                                                  # Importting matplotlib for Plotting and visualizing images
import math                                                                                      # Importing math module to perform mathematical operations
import cv2                                                                                       # Importing openCV for image processing
import seaborn as sns                                                                            # Importing seaborn to plot graphs


# Tensorflow modules
import tensorflow as tf
from tensorflow.keras.preprocessing.image import ImageDataGenerator                              # Importing the ImageDataGenerator for data augmentation
from tensorflow.keras.models import Sequential                                                   # Importing the sequential module to define a sequential model
from tensorflow.keras.layers import Dense,Dropout,Flatten,Conv2D,MaxPooling2D,BatchNormalization # Defining all the layers to build our CNN Model
from tensorflow.keras.optimizers import Adam,SGD                                                 # Importing the optimizers which can be used in our model
from sklearn import preprocessing                                                                # Importing the preprocessing module to preprocess the data
from sklearn.model_selection import train_test_split                                             # Importing train_test_split function to split the data into train and test
from sklearn.metrics import confusion_matrix                                                     # Importing confusion_matrix to plot the confusion matrix

# Display images using OpenCV
from google.colab.patches import cv2_imshow                                                      # Importing cv2_imshow from google.patches to display images

# Ignore warnings
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# ## **Reading the dataset**

# %%
# Mount Google drive to access the dataset (monkeys_dataset.zip)
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# Load the image file of the dataset
images = np.load('/content/drive/MyDrive/greatlearningfiles/newf/images.npy')

# Load the labels file of the dataset
labels = pd.read_csv('/content/drive/MyDrive/greatlearningfiles/newf/Labels.csv')

# %% [markdown]
# ## **Overview of the dataset**
#
#
# Let's print the shape of the images and labels

# %%
print(images.shape)
print(labels.shape)
# Out:
# (1342, 128, 128, 3)
# (1342, 1)

# %% [markdown]
# There are 1342 RGB  images of shape 128 x 128 X 3, each image having 3 channels.

# %% [markdown]
# ## Plotting images using OpenCV and matplotlib

# %%
cv2_imshow(images[5])
# Out:
# <PIL.Image.Image image mode=RGB size=128x128>

# %%
plt.imshow(images[5])

# %% [markdown]
# - We can observe that the images are being shown in different colors when plotted with openCV and matplotlib as OpenCV reads images in BGR format and this shows that the given numpy arrays were generated from the original images using OpenCV.
# - Now we will convert these BGR images to RGB images so we could interpret them easily.

# %%
# Converting the images from BGR to RGB using cvtColor function of OpenCV
for i in range(len(images)):
  images[i] = cv2.cvtColor(images[i], cv2.COLOR_BGR2RGB)

# %%
plt.imshow(images[5])

# %% [markdown]
# ## **Exploratory Data Analysis**

# %%
def plot_images(images,labels):
  num_classes=10                                                                  # Number of Classes
  categories=np.unique(labels)
  keys=dict(labels['Label'])                                                      # Obtaing the unique classes from y_train
  rows = 3                                                                        # Defining number of rows=3
  cols = 4                                                                        # Defining number of columns=4
  fig = plt.figure(figsize=(10, 8))                                               # Defining the figure size to 10x8
  for i in range(cols):
      for j in range(rows):
          random_index = np.random.randint(0, len(labels))                        # Generating random indices from the data and plotting the images
          ax = fig.add_subplot(rows, cols, i * rows + j + 1)                      # Adding subplots with 3 rows and 4 columns
          ax.imshow(images[random_index, :])                                      # Plotting the image
          ax.set_title(keys[random_index])
  plt.show()

# %%
plot_images(images,labels)

# %% [markdown]
# <b> Checking for data imbalance

# %%
 sns.countplot(x = labels['Label'])
 plt.xticks(rotation='vertical')
 plt.show()

# %% [markdown]
# - As you can see from the above plot, the dataset is quite balanced.
# - There are about 135 images in each category

# %% [markdown]
# ### Resizing images
# As the size of the images is large, it may be computationally expensive to train on these larger images; therefore, it is preferable to reduce the image size from 128 to 64.

# %%
images_decreased=[]
height = 64
width = 64
dimensions = (width, height)
for i in range(len(images)):
  images_decreased.append( cv2.resize(images[i], dimensions, interpolation=cv2.INTER_LINEAR))

# %%
plt.imshow(images_decreased[3])

# %% [markdown]
# ## Visualizing images using Gaussian Blur

# %%
# Applying Gaussian Blur to denoise the images
images_gb=[]
for i in range(len(images)):
  # gb[i] = cv2.cvtColor(images[i], cv2.COLOR_BGR2RGB)
  images_gb.append(cv2.GaussianBlur(images[i], ksize =(3,3),sigmaX =  0))

# %%
plt.imshow(images_gb[3])

# %% [markdown]
# - It appears that GaussianBlur would be ineffective because the blurred or denoised image does not seem to contain any relevant information, and the model would struggle to categorize these blurred images.

# %% [markdown]
# ## **Splitting the dataset**
#
# - As we have less images in our dataset, we will only use 10% of our data for testing, 10% of our data for validation and 80% of our data for training.
# - We are using the train_test_split() function from scikit-learn. Here, we split the dataset into three parts, train,test and validation.

# %%
from sklearn.model_selection import train_test_split
X_temp, X_test, y_temp, y_test = train_test_split(np.array(images),labels , test_size=0.1, random_state=42,stratify=labels)
X_train, X_val, y_train, y_val = train_test_split(X_temp,y_temp , test_size=0.1, random_state=42,stratify=y_temp)

# %%
print(X_train.shape,y_train.shape)
print(X_val.shape,y_val.shape)
print(X_test.shape,y_test.shape)
# Out:
# (1086, 128, 128, 3) (1086, 1)
# (121, 128, 128, 3) (121, 1)
# (135, 128, 128, 3) (135, 1)

# %% [markdown]
# ## **Making the data compatible:**
#
# - Convert labels from names to one hot vectors
# - Normalizing the values

# %% [markdown]
# ## Encoding the target labels

# %%
# Convert labels from names to one hot vectors.
# We have already used encoding methods like onehotencoder and labelencoder earlier so now we will be using a new encoding method called labelBinarizer.
# Labelbinarizer works similar to onehotencoder

from sklearn.preprocessing import LabelBinarizer
enc = LabelBinarizer()
y_train_encoded = enc.fit_transform(y_train)
y_val_encoded=enc.transform(y_val)
y_test_encoded=enc.transform(y_test)

# %% [markdown]
# ## Data Normalization
# Since the **image pixel values range from 0-255**, our method of normalization here will be **scaling** - we shall **divide all the pixel values by 255 to standardize the images to have values between 0-1.**

# %%
# Normalizing the image pixels
X_train_normalized = X_train.astype('float32')/255.0
X_val_normalized = X_val.astype('float32')/255.0
X_test_normalized = X_test.astype('float32')/255.0

# %% [markdown]
# ## **Model Building - Convolutional Neural Network (CNN)**
# Let's create a CNN model sequentially, where we will be adding the layers one after another.

# %% [markdown]
# First, we need to clear the previous model's history from the session even if a single model can run multiple times on the same data.
#
# In Keras, we need a special command to clear the model's history, otherwise the previous model history remains in the backend.
#
# Also, let's fix the seed again after clearing the backend.
#
# Let's **set the seed for random number generators in Numpy, the Random library in Python, and in TensorFlow** to be able to reproduce the same results every time we run the code.

# %%
# Clearing backend
from tensorflow.keras import backend
backend.clear_session()

# %%
# Fixing the seed for random number generators
import random
np.random.seed(42)
random.seed(42)
tf.random.set_seed(42)

# %% [markdown]
# Now, let's build a **CNN Model** with the following 2 main parts - <br>
#
# 1. **The Feature Extraction layers** which are comprised of convolutional and pooling layers.
# 2. **The Fully Connected classification layers** for prediction.<br><br>

# %%
# Intializing a sequential model
model = Sequential()

# Adding first conv layer with 64 filters and kernel size 3x3 , padding 'same' provides the output size same as the input size
# Input_shape denotes input image dimension of images
model.add(Conv2D(64, (3, 3), activation='relu', padding="same", input_shape=(128, 128, 3)))

# Adding max pooling to reduce the size of output of first conv layer
model.add(MaxPooling2D((2, 2), padding = 'same'))

model.add(Conv2D(32, (3, 3), activation='relu', padding="same"))
model.add(MaxPooling2D((2, 2), padding = 'same'))

# flattening the output of the conv layer after max pooling to make it ready for creating dense connections
model.add(Flatten())

# Adding a fully connected dense layer with 100 neurons
model.add(Dense(16, activation='relu'))
model.add(Dropout(0.3))
# Adding the output layer with 10 neurons and activation functions as softmax since this is a multi-class classification problem
model.add(Dense(10, activation='softmax'))

# Using SGD Optimizer
# opt = SGD(learning_rate=0.01, momentum=0.9)
opt=Adam()
# Compile model
model.compile(optimizer=opt, loss='categorical_crossentropy', metrics=['accuracy'])

# Generating the summary of the model
model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_2 (Conv2D)           (None, 128, 128, 64)      1792
#
#  max_pooling2d_2 (MaxPoolin  (None, 64, 64, 64)        0
#  g2D)
#
#  conv2d_3 (Conv2D)           (None, 64, 64, 32)        18464
#
#  max_pooling2d_3 (MaxPoolin  (None, 32, 32, 32)        0
#  g2D)
#
#  flatten_1 (Flatten)         (None, 32768)             0
#
#  dense_2 (Dense)             (None, 16)                524304
#
#  dropout_1 (Dropout)         (None, 16)                0
#
#  dense_3 (Dense)             (None, 10)                170
#
# =================================================================
# Total params: 544730 (2.08 MB)
# Trainable params: 544730 (2.08 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %% [markdown]
# ### <b> Fitting the model on the train data

# %%
history_1 = model.fit(
            X_train_normalized, y_train_encoded,
            epochs=30,
            validation_data=(X_val_normalized,y_val_encoded),
            batch_size=32,
            verbose=2
)
# Out:
# Epoch 1/30
# 34/34 - 4s - loss: 2.3207 - accuracy: 0.1308 - val_loss: 2.2803 - val_accuracy: 0.1653 - 4s/epoch - 115ms/step
# Epoch 2/30
# 34/34 - 1s - loss: 2.2637 - accuracy: 0.1676 - val_loss: 2.1682 - val_accuracy: 0.1983 - 1s/epoch - 30ms/step
# Epoch 3/30
# 34/34 - 1s - loss: 2.1144 - accuracy: 0.2210 - val_loss: 2.0492 - val_accuracy: 0.2727 - 1s/epoch - 39ms/step
# Epoch 4/30
# 34/34 - 1s - loss: 1.9715 - accuracy: 0.3011 - val_loss: 1.9161 - val_accuracy: 0.3471 - 892ms/epoch - 26ms/step
# Epoch 5/30
# 34/34 - 1s - loss: 1.9244 - accuracy: 0.3011 - val_loss: 1.9115 - val_accuracy: 0.3471 - 643ms/epoch - 19ms/step
# Epoch 6/30
# 34/34 - 1s - loss: 1.8179 - accuracy: 0.3278 - val_loss: 1.7891 - val_accuracy: 0.3719 - 576ms/epoch - 17ms/step
# Epoch 7/30
# 34/34 - 1s - loss: 1.6840 - accuracy: 0.3877 - val_loss: 1.7102 - val_accuracy: 0.3719 - 585ms/epoch - 17ms/step
# Epoch 8/30
# 34/34 - 1s - loss: 1.5679 - accuracy: 0.4088 - val_loss: 1.6405 - val_accuracy: 0.3967 - 618ms/epoch - 18ms/step
# Epoch 9/30
# 34/34 - 1s - loss: 1.5060 - accuracy: 0.4217 - val_loss: 1.6241 - val_accuracy: 0.4298 - 627ms/epoch - 18ms/step
# Epoch 10/30
# 34/34 - 1s - loss: 1.4277 - accuracy: 0.4567 - val_loss: 1.5618 - val_accuracy: 0.4298 - 622ms/epoch - 18ms/step
# Epoch 11/30
# 34/34 - 1s - loss: 1.3248 - accuracy: 0.4936 - val_loss: 1.5654 - val_accuracy: 0.4793 - 581ms/epoch - 17ms/step
# Epoch 12/30
# 34/34 - 1s - loss: 1.2283 - accuracy: 0.5313 - val_loss: 1.5241 - val_accuracy: 0.4628 - 622ms/epoch - 18ms/step
# Epoch 13/30
# 34/34 - 1s - loss: 1.1703 - accuracy: 0.5276 - val_loss: 1.5224 - val_accuracy: 0.4793 - 631ms/epoch - 19ms/step
# Epoch 14/30
# 34/34 - 1s - loss: 1.1225 - accuracy: 0.5552 - val_loss: 1.5493 - val_accuracy: 0.4959 - 588ms/epoch - 17ms/step
# Epoch 15/30
# 34/34 - 1s - loss: 1.0241 - accuracy: 0.5967 - val_loss: 1.5478 - val_accuracy: 0.4545 - 626ms/epoch - 18ms/step
# Epoch 16/30
# 34/34 - 1s - loss: 1.0535 - accuracy: 0.5976 - val_loss: 1.5302 - val_accuracy: 0.5041 - 616ms/epoch - 18ms/step
# Epoch 17/30
# 34/34 - 1s - loss: 0.9996 - accuracy: 0.6206 - val_loss: 1.5009 - val_accuracy: 0.5124 - 628ms/epoch - 18ms/step
# Epoch 18/30
# 34/34 - 1s - loss: 0.9161 - accuracy: 0.6363 - val_loss: 1.6660 - val_accuracy: 0.4959 - 578ms/epoch - 17ms/step
# Epoch 19/30
# 34/34 - 1s - loss: 0.9342 - accuracy: 0.6317 - val_loss: 1.5872 - val_accuracy: 0.4959 - 629ms/epoch - 19ms/step
# Epoch 20/30
# 34/34 - 1s - loss: 0.8878 - accuracy: 0.6676 - val_loss: 1.8271 - val_accuracy: 0.4463 - 651ms/epoch - 19ms/step
# Epoch 21/30
# 34/34 - 1s - loss: 0.9024 - accuracy: 0.6427 - val_loss: 1.7503 - val_accuracy: 0.4628 - 629ms/epoch - 18ms/step
# Epoch 22/30
# 34/34 - 1s - loss: 0.8802 - accuracy: 0.6639 - val_loss: 1.6961 - val_accuracy: 0.4793 - 668ms/epoch - 20ms/step
# Epoch 23/30
# 34/34 - 1s - loss: 0.8933 - accuracy: 0.6510 - val_loss: 1.8258 - val_accuracy: 0.4380 - 663ms/epoch - 20ms/step
# Epoch 24/30
# 34/34 - 1s - loss: 0.8699 - accuracy: 0.6639 - val_loss: 2.1310 - val_accuracy: 0.4628 - 657ms/epoch - 19ms/step
# Epoch 25/30
# 34/34 - 1s - loss: 0.8529 - accuracy: 0.6805 - val_loss: 2.0978 - val_accuracy: 0.4628 - 603ms/epoch - 18ms/step
# Epoch 26/30
# 34/34 - 1s - loss: 0.8659 - accuracy: 0.6602 - val_loss: 2.0849 - val_accuracy: 0.4628 - 608ms/epoch - 18ms/step
# Epoch 27/30
# 34/34 - 1s - loss: 0.8137 - accuracy: 0.6869 - val_loss: 2.0291 - val_accuracy: 0.4793 - 590ms/epoch - 17ms/step
# Epoch 28/30
# 34/34 - 1s - loss: 0.8034 - accuracy: 0.6814 - val_loss: 1.9640 - val_accuracy: 0.4876 - 603ms/epoch - 18ms/step
# Epoch 29/30
# 34/34 - 1s - loss: 0.7658 - accuracy: 0.7035 - val_loss: 2.1372 - val_accuracy: 0.5041 - 596ms/epoch - 18ms/step
# Epoch 30/30
# 34/34 - 1s - loss: 0.7257 - accuracy: 0.7164 - val_loss: 2.1269 - val_accuracy: 0.4711 - 586ms/epoch - 17ms/step

# %% [markdown]
# ### **Model Evaluation**

# %%
plt.plot(history_1.history['accuracy'])
plt.plot(history_1.history['val_accuracy'])
plt.title('Model Accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(['Train', 'Validation'], loc='upper left')
plt.show()

# %% [markdown]
# **Observations:**
#
#
# *   We can see from the above plot that **the training accuracy of the  model was good but the validation accuracy was not good.**
# *   The model seems to overfit on the data.

# %% [markdown]
# ### **Evaluating the model on test data**

# %%
accuracy = model.evaluate(X_test_normalized, y_test_encoded, verbose=2)
# Out:
# 5/5 - 0s - loss: 1.8162 - accuracy: 0.5630 - 185ms/epoch - 37ms/step

# %% [markdown]
# ### **Generating the predictions using test data**

# %%
# Here we would get the output as probablities for each category
y_pred=model.predict(X_test_normalized)
# Out:
# 5/5 [==============================] - 0s 6ms/step

# %%
# y_pred

# %% [markdown]
# ### **Plotting the Confusion Matrix**

# %% [markdown]
# *   The Confusion matrix is also defined as an inbuilt function in the TensorFlow module, so we can use that for evaluating the classification model.
# *   The Confusion matrix expects categorical data as input. However, y_test_encoded is an encoded value, whereas y_pred has probabilities. So,we must retrieve the categorical values from the encoded values.
# *   We will use the `argmax()` function to obtain the maximum value over each category on both y_test_encoded and y_pred and obtain their respective classes.

# %%
# Obtaining the categorical values from y_test_encoded and y_pred
y_pred_arg=np.argmax(y_pred,axis=1)
y_test_arg=np.argmax(y_test_encoded,axis=1)

# Plotting the Confusion Matrix using confusion matrix() function which is also predefined tensorflow module
confusion_matrix = tf.math.confusion_matrix(y_test_arg,y_pred_arg)
f, ax = plt.subplots(figsize=(10, 8))
sns.heatmap(
    confusion_matrix,
    annot=True,
    linewidths=.4,
    fmt="d",
    square=True,
    ax=ax
)
plt.show()

# %%
from sklearn.metrics import classification_report

# %%
print(classification_report(y_test_arg,y_pred_arg))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.60      0.86      0.71        14
#            1       0.56      0.69      0.62        13
#            2       0.60      0.21      0.32        14
#            3       0.53      0.71      0.61        14
#            4       0.60      0.69      0.64        13
#            5       0.62      0.62      0.62        13
#            6       0.88      0.50      0.64        14
#            7       0.31      0.38      0.34        13
#            8       0.75      0.46      0.57        13
#            9       0.47      0.50      0.48        14
#
#     accuracy                           0.56       135
#    macro avg       0.59      0.56      0.55       135
# weighted avg       0.59      0.56      0.55       135

# %% [markdown]
# <b> Observations</b><br>
# - We observe that some of the classes are not predicted correctly.
# - In comparison to the rest, we can see that classes 0,3, and 4 are well classified.
# - We can also observe that classes 1,2,5,7 and 9 are mostly misclassified.

# %% [markdown]
# # Model-2
#
# As we can see, our initial model appears to overfit. Therefore we'll try to address this problem with data augmentation and Batch Normalization to check if we can improve the model's performance.

# %% [markdown]
# ## **Data Augmentation**
#
# In most of the real-world case studies, it is challenging to acquire a large number of images and then train CNNs. To overcome this problem, one approach we might consider is **Data Augmentation**. CNNs have the property of **translational invariance**, which means they can recognise an object even if its appearance shifts translationally in some way. <br> Taking this attribute into account, we can augment the images using the techniques listed below - <br>
# **1. Horizontal Flip** (should be set to True/False) <br>
# **2. Vertical Flip** (should be set to True/False) <br>
# **3. Height Shift** (should be between 0 and 1) <br>
# **4. Width Shift** (should be between 0 and 1) <br>
# **5. Rotation** (should be between 0 and 180) <br>
# **6. Shear** (should be between 0 and 1) <br>
# **7. Zoom** (should be between 0 and 1) etc. <br>
#
# Remember, **data augmentation should not be used in the validation/test data set**.

# %%
# Clearing backend
from tensorflow.keras import backend
backend.clear_session()

# Fixing the seed for random number generators
import random
np.random.seed(42)
random.seed(42)
tf.random.set_seed(42)

# %%
# All images to be rescaled by 1/255.
train_datagen = ImageDataGenerator(
                              rotation_range=20,horizontal_flip = True,
                              fill_mode='nearest'
                              )
# test_datagen  = ImageDataGenerator(rescale = 1.0/255.)

# %%
# Intializing a sequential model
model = Sequential()

# Adding first conv layer with 64 filters and kernel size 3x3 , padding 'same' provides the output size same as the input size
# Input_shape denotes input image dimension images
model.add(Conv2D(64, (3, 3), activation='relu', padding="same", input_shape=(128, 128, 3)))

# Adding max pooling to reduce the size of output of first conv layer
model.add(MaxPooling2D((2, 2), padding = 'same'))
# model.add(BatchNormalization())
model.add(Conv2D(32, (3, 3), activation='relu', padding="same"))
model.add(MaxPooling2D((2, 2), padding = 'same'))
model.add(BatchNormalization())
# flattening the output of the conv layer after max pooling to make it ready for creating dense connections
model.add(Flatten())

# Adding a fully connected dense layer with 100 neurons
model.add(Dense(16, activation='relu'))
model.add(Dropout(0.3))
# Adding the output layer with 10 neurons and activation functions as softmax since this is a multi-class classification problem
model.add(Dense(10, activation='softmax'))

# Using SGD Optimizer
# opt = SGD(learning_rate=0.01, momentum=0.9)
opt=Adam()
# Compile model
model.compile(optimizer=opt, loss='categorical_crossentropy', metrics=['accuracy'])

# Generating the summary of the model
model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_2 (Conv2D)           (None, 128, 128, 64)      1792
#
#  max_pooling2d_2 (MaxPoolin  (None, 64, 64, 64)        0
#  g2D)
#
#  conv2d_3 (Conv2D)           (None, 64, 64, 32)        18464
#
#  max_pooling2d_3 (MaxPoolin  (None, 32, 32, 32)        0
#  g2D)
#
#  batch_normalization_1 (Bat  (None, 32, 32, 32)        128
#  chNormalization)
#
#  flatten_1 (Flatten)         (None, 32768)             0
#
#  dense_2 (Dense)             (None, 16)                524304
#
#  dropout_1 (Dropout)         (None, 16)                0
#
#  dense_3 (Dense)             (None, 10)                170
#
# =================================================================
# Total params: 544858 (2.08 MB)
# Trainable params: 544794 (2.08 MB)
# Non-trainable params: 64 (256.00 Byte)
# _________________________________________________________________

# %%
X_train_normalized.shape[0] /64
# Out:
# 16.96875

# %%
# Epochs
epochs = 25
# Batch size
batch_size = 64

history = model.fit(train_datagen.flow(X_train_normalized,y_train_encoded,
                                       batch_size=batch_size,
                                       seed=42,
                                       shuffle=False),
                    epochs=epochs,
                    steps_per_epoch=X_train_normalized.shape[0] /batch_size,
                    validation_data=(X_val_normalized,y_val_encoded),
                    verbose=1)
# Out:
# Epoch 1/25
# 16/16 [==============================] - 10s 203ms/step - loss: 2.3877 - accuracy: 0.1492 - val_loss: 2.2874 - val_accuracy: 0.1322
# Epoch 2/25
# 16/16 [==============================] - 4s 215ms/step - loss: 2.1248 - accuracy: 0.2044 - val_loss: 2.2796 - val_accuracy: 0.1405
# Epoch 3/25
# 16/16 [==============================] - 5s 285ms/step - loss: 1.9932 - accuracy: 0.2735 - val_loss: 2.2539 - val_accuracy: 0.1901
# Epoch 4/25
# 16/16 [==============================] - 4s 229ms/step - loss: 1.8562 - accuracy: 0.3149 - val_loss: 2.2461 - val_accuracy: 0.2066
# Epoch 5/25
# 16/16 [==============================] - 4s 212ms/step - loss: 1.7463 - accuracy: 0.3591 - val_loss: 2.2411 - val_accuracy: 0.2149
# Epoch 6/25
# 16/16 [==============================] - 5s 276ms/step - loss: 1.5836 - accuracy: 0.4429 - val_loss: 2.2006 - val_accuracy: 0.2149
# Epoch 7/25
# 16/16 [==============================] - 4s 213ms/step - loss: 1.5229 - accuracy: 0.4346 - val_loss: 2.2290 - val_accuracy: 0.1983
# Epoch 8/25
# 16/16 [==============================] - 4s 211ms/step - loss: 1.4911 - accuracy: 0.4650 - val_loss: 2.1809 - val_accuracy: 0.2562
# Epoch 9/25
# 16/16 [==============================] - 6s 333ms/step - loss: 1.3569 - accuracy: 0.5055 - val_loss: 2.1469 - val_accuracy: 0.2397
# Epoch 10/25
# 16/16 [==============================] - 4s 215ms/step - loss: 1.3230 - accuracy: 0.5138 - val_loss: 2.1265 - val_accuracy: 0.2479
# Epoch 11/25
# 16/16 [==============================] - 4s 212ms/step - loss: 1.2477 - accuracy: 0.5525 - val_loss: 2.1209 - val_accuracy: 0.3058
# Epoch 12/25
# 16/16 [==============================] - 4s 248ms/step - loss: 1.2640 - accuracy: 0.5368 - val_loss: 2.0307 - val_accuracy: 0.3471
# Epoch 13/25
# 16/16 [==============================] - 4s 213ms/step - loss: 1.2458 - accuracy: 0.5645 - val_loss: 2.0297 - val_accuracy: 0.2397
# Epoch 14/25
# 16/16 [==============================] - 4s 244ms/step - loss: 1.2205 - accuracy: 0.5635 - val_loss: 1.9597 - val_accuracy: 0.3306
# Epoch 15/25
# 16/16 [==============================] - 4s 231ms/step - loss: 1.1504 - accuracy: 0.5764 - val_loss: 1.8697 - val_accuracy: 0.4132
# Epoch 16/25
# 16/16 [==============================] - 4s 215ms/step - loss: 1.0697 - accuracy: 0.6234 - val_loss: 1.8495 - val_accuracy: 0.3967
# Epoch 17/25
# 16/16 [==============================] - 5s 295ms/step - loss: 1.0226 - accuracy: 0.6381 - val_loss: 1.8286 - val_accuracy: 0.3471
# Epoch 18/25
# 16/16 [==============================] - 4s 212ms/step - loss: 0.9571 - accuracy: 0.6427 - val_loss: 1.8074 - val_accuracy: 0.4380
# Epoch 19/25
# 16/16 [==============================] - 4s 212ms/step - loss: 0.9872 - accuracy: 0.6354 - val_loss: 1.8527 - val_accuracy: 0.3802
# Epoch 20/25
# 16/16 [==============================] - 5s 307ms/step - loss: 1.0137 - accuracy: 0.6409 - val_loss: 1.7349 - val_accuracy: 0.4463
# Epoch 21/25
# 16/16 [==============================] - 4s 213ms/step - loss: 0.9541 - accuracy: 0.6483 - val_loss: 1.6835 - val_accuracy: 0.4628
# Epoch 22/25
# 16/16 [==============================] - 5s 316ms/step - loss: 0.9055 - accuracy: 0.6602 - val_loss: 1.5806 - val_accuracy: 0.4628
# Epoch 23/25
# 16/16 [==============================] - 4s 211ms/step - loss: 0.8790 - accuracy: 0.6713 - val_loss: 1.7045 - val_accuracy: 0.4298
# Epoch 24/25
# 16/16 [==============================] - 4s 214ms/step - loss: 0.8337 - accuracy: 0.6888 - val_loss: 1.4688 - val_accuracy: 0.5372
# Epoch 25/25
# 16/16 [==============================] - 4s 264ms/step - loss: 0.8587 - accuracy: 0.6823 - val_loss: 1.4985 - val_accuracy: 0.4876

# %%
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('Model Accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(['Train', 'Validation'], loc='upper left')
plt.show()

# %%
accuracy = model.evaluate(X_test_normalized, y_test_encoded, verbose=2)
# Out:
# 5/5 - 0s - loss: 1.3884 - accuracy: 0.5333 - 73ms/epoch - 15ms/step

# %% [markdown]
# We can observe that our accuracy has improved compared to our previous model.

# %%
# Here we would get the output as probablities for each category
y_pred=model.predict(X_test_normalized)
# Out:
# 5/5 [==============================] - 0s 6ms/step

# %%
# Obtaining the categorical values from y_test_encoded and y_pred
y_pred_arg=np.argmax(y_pred,axis=1)
y_test_arg=np.argmax(y_test_encoded,axis=1)

# Plotting the Confusion Matrix using confusion matrix() function which is also predefined tensorflow module
confusion_matrix = tf.math.confusion_matrix(y_test_arg,y_pred_arg)
f, ax = plt.subplots(figsize=(10, 8))
sns.heatmap(
    confusion_matrix,
    annot=True,
    linewidths=.4,
    fmt="d",
    square=True,
    ax=ax
)
plt.show()

# %%
print(classification_report(y_test_arg,y_pred_arg))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.82      1.00      0.90        14
#            1       0.75      0.46      0.57        13
#            2       0.38      0.57      0.46        14
#            3       1.00      0.14      0.25        14
#            4       0.56      0.69      0.62        13
#            5       0.32      0.69      0.44        13
#            6       0.62      0.36      0.45        14
#            7       0.36      0.31      0.33        13
#            8       0.71      0.77      0.74        13
#            9       0.50      0.36      0.42        14
#
#     accuracy                           0.53       135
#    macro avg       0.60      0.54      0.52       135
# weighted avg       0.61      0.53      0.52       135

# %% [markdown]
# **Observation:**
# - The confusion matrix appears to be improving as well, however there is still some confusion with the 3,5,7 classes of monkey species.
# - The 5th class is the most confused class among all.
# - We can observe that this model has outperformed our previous model.

# %% [markdown]
# # Transfer Learning using VGG16

# %% [markdown]
# - Let's try again, but this time, we will be using the idea of **Transfer Learning**. We will be loading a pre-built architecture - **VGG16**, which was trained on the ImageNet dataset and is the runner-up in the ImageNet competition in 2014.
#
# - For training VGG16, we will directly use the convolutional and pooling layers and freeze their weights i.e. no training will be done on them. For classification, we will replace the existing fully-connected layers with FC layers created specifically for our problem.

# %%
from tensorflow.keras.models import Model
from keras.applications.vgg16 import VGG16

vgg_model = VGG16(weights='imagenet', include_top = False, input_shape = (128,128,3))
vgg_model.summary()
# Out:
# Model: "vgg16"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_2 (InputLayer)        [(None, 128, 128, 3)]     0
#
#  block1_conv1 (Conv2D)       (None, 128, 128, 64)      1792
#
#  block1_conv2 (Conv2D)       (None, 128, 128, 64)      36928
#
#  block1_pool (MaxPooling2D)  (None, 64, 64, 64)        0
#
#  block2_conv1 (Conv2D)       (None, 64, 64, 128)       73856
#
#  block2_conv2 (Conv2D)       (None, 64, 64, 128)       147584
#
#  block2_pool (MaxPooling2D)  (None, 32, 32, 128)       0
#
#  block3_conv1 (Conv2D)       (None, 32, 32, 256)       295168
#
#  block3_conv2 (Conv2D)       (None, 32, 32, 256)       590080
#
#  block3_conv3 (Conv2D)       (None, 32, 32, 256)       590080
#
#  block3_pool (MaxPooling2D)  (None, 16, 16, 256)       0
#
#  block4_conv1 (Conv2D)       (None, 16, 16, 512)       1180160
#
#  block4_conv2 (Conv2D)       (None, 16, 16, 512)       2359808
#
#  block4_conv3 (Conv2D)       (None, 16, 16, 512)       2359808
#
#  block4_pool (MaxPooling2D)  (None, 8, 8, 512)         0
#
#  block5_conv1 (Conv2D)       (None, 8, 8, 512)         2359808
#
#  block5_conv2 (Conv2D)       (None, 8, 8, 512)         2359808
#
#  block5_conv3 (Conv2D)       (None, 8, 8, 512)         2359808
#
#  block5_pool (MaxPooling2D)  (None, 4, 4, 512)         0
#
# =================================================================
# Total params: 14714688 (56.13 MB)
# Trainable params: 14714688 (56.13 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
# vgg_model = VGG16(weights='imagenet', include_top = True, input_shape = (224,224,3)) ### for using orginal arch we need to use 224*224 size
# vgg_model.summary()

# %%
# Making all the layers of the VGG model non-trainable. i.e. freezing them
for layer in vgg_model.layers:
    layer.trainable = False

# %%
vgg_model.summary()
# Out:
# Model: "vgg16"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_2 (InputLayer)        [(None, 128, 128, 3)]     0
#
#  block1_conv1 (Conv2D)       (None, 128, 128, 64)      1792
#
#  block1_conv2 (Conv2D)       (None, 128, 128, 64)      36928
#
#  block1_pool (MaxPooling2D)  (None, 64, 64, 64)        0
#
#  block2_conv1 (Conv2D)       (None, 64, 64, 128)       73856
#
#  block2_conv2 (Conv2D)       (None, 64, 64, 128)       147584
#
#  block2_pool (MaxPooling2D)  (None, 32, 32, 128)       0
#
#  block3_conv1 (Conv2D)       (None, 32, 32, 256)       295168
#
#  block3_conv2 (Conv2D)       (None, 32, 32, 256)       590080
#
#  block3_conv3 (Conv2D)       (None, 32, 32, 256)       590080
#
#  block3_pool (MaxPooling2D)  (None, 16, 16, 256)       0
#
#  block4_conv1 (Conv2D)       (None, 16, 16, 512)       1180160
#
#  block4_conv2 (Conv2D)       (None, 16, 16, 512)       2359808
#
#  block4_conv3 (Conv2D)       (None, 16, 16, 512)       2359808
#
#  block4_pool (MaxPooling2D)  (None, 8, 8, 512)         0
#
#  block5_conv1 (Conv2D)       (None, 8, 8, 512)         2359808
#
#  block5_conv2 (Conv2D)       (None, 8, 8, 512)         2359808
#
#  block5_conv3 (Conv2D)       (None, 8, 8, 512)         2359808
#
#  block5_pool (MaxPooling2D)  (None, 4, 4, 512)         0
#
# =================================================================
# Total params: 14714688 (56.13 MB)
# Trainable params: 0 (0.00 Byte)
# Non-trainable params: 14714688 (56.13 MB)
# _________________________________________________________________

# %%
new_model = Sequential()

# Adding the convolutional part of the VGG16 model from above
new_model.add(vgg_model)

# Flattening the output of the VGG16 model because it is from a convolutional layer
new_model.add(Flatten())

# Adding a dense output layer
new_model.add(Dense(32, activation='relu'))
new_model.add(Dropout(0.2))
new_model.add(Dense(16, activation='relu'))
new_model.add(Dense(10, activation='softmax'))
opt=Adam()
# Compile model
new_model.compile(optimizer=opt, loss='categorical_crossentropy', metrics=['accuracy'])

# Generating the summary of the model
new_model.summary()
# Out:
# Model: "sequential_4"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  vgg16 (Functional)          (None, 4, 4, 512)         14714688
#
#  flatten_4 (Flatten)         (None, 8192)              0
#
#  dense_10 (Dense)            (None, 32)                262176
#
#  dropout_4 (Dropout)         (None, 32)                0
#
#  dense_11 (Dense)            (None, 16)                528
#
#  dense_12 (Dense)            (None, 10)                170
#
# =================================================================
# Total params: 14977562 (57.13 MB)
# Trainable params: 262874 (1.00 MB)
# Non-trainable params: 14714688 (56.13 MB)
# _________________________________________________________________

# %%
es = tf.keras.callbacks.EarlyStopping(
    monitor='val_loss',
    min_delta=0.001,
    patience=10,
    verbose=0,
    mode='auto',
    baseline=None,
    restore_best_weights=False,
    start_from_epoch=0
)

# %%
# Epochs
epochs = 79
# Batch size
batch_size = 64

history_vgg16 = new_model.fit(train_datagen.flow(X_train_normalized,y_train_encoded,
                                       batch_size=batch_size,
                                       seed=42,
                                       shuffle=False),
                    epochs=epochs,
                    steps_per_epoch=X_train_normalized.shape[0] // batch_size,
                    validation_data=(X_val_normalized,y_val_encoded),
                    verbose=1,callbacks = [es])
# Out:
# Epoch 1/79
# 16/16 [==============================] - 6s 256ms/step - loss: 2.3162 - accuracy: 0.1497 - val_loss: 2.1580 - val_accuracy: 0.2314
# Epoch 2/79
# 16/16 [==============================] - 5s 310ms/step - loss: 2.1276 - accuracy: 0.2192 - val_loss: 2.0371 - val_accuracy: 0.2975
# Epoch 3/79
# 16/16 [==============================] - 4s 258ms/step - loss: 1.9804 - accuracy: 0.2750 - val_loss: 1.8707 - val_accuracy: 0.3058
# Epoch 4/79
# 16/16 [==============================] - 4s 246ms/step - loss: 1.8793 - accuracy: 0.3249 - val_loss: 1.8094 - val_accuracy: 0.3471
# Epoch 5/79
# 16/16 [==============================] - 5s 337ms/step - loss: 1.7675 - accuracy: 0.3611 - val_loss: 1.6710 - val_accuracy: 0.4132
# Epoch 6/79
# 16/16 [==============================] - 4s 243ms/step - loss: 1.6754 - accuracy: 0.4149 - val_loss: 1.5780 - val_accuracy: 0.4545
# Epoch 7/79
# 16/16 [==============================] - 5s 319ms/step - loss: 1.5925 - accuracy: 0.4413 - val_loss: 1.5630 - val_accuracy: 0.4545
# Epoch 8/79
# 16/16 [==============================] - 4s 248ms/step - loss: 1.4808 - accuracy: 0.5039 - val_loss: 1.4203 - val_accuracy: 0.5620
# Epoch 9/79
# 16/16 [==============================] - 4s 249ms/step - loss: 1.3687 - accuracy: 0.5431 - val_loss: 1.3441 - val_accuracy: 0.5537
# Epoch 10/79
# 16/16 [==============================] - 5s 281ms/step - loss: 1.2867 - accuracy: 0.5705 - val_loss: 1.3007 - val_accuracy: 0.5372
# Epoch 11/79
# 16/16 [==============================] - 4s 252ms/step - loss: 1.2533 - accuracy: 0.5841 - val_loss: 1.2463 - val_accuracy: 0.5455
# Epoch 12/79
# 16/16 [==============================] - 5s 305ms/step - loss: 1.1947 - accuracy: 0.5998 - val_loss: 1.1993 - val_accuracy: 0.5785
# Epoch 13/79
# 16/16 [==============================] - 4s 259ms/step - loss: 1.1235 - accuracy: 0.6233 - val_loss: 1.1848 - val_accuracy: 0.5868
# Epoch 14/79
# 16/16 [==============================] - 4s 251ms/step - loss: 1.0454 - accuracy: 0.6663 - val_loss: 1.1402 - val_accuracy: 0.6198
# Epoch 15/79
# 16/16 [==============================] - 5s 302ms/step - loss: 1.0096 - accuracy: 0.6575 - val_loss: 1.1647 - val_accuracy: 0.5868
# Epoch 16/79
# 16/16 [==============================] - 5s 275ms/step - loss: 0.9948 - accuracy: 0.6712 - val_loss: 1.1211 - val_accuracy: 0.5950
# Epoch 17/79
# 16/16 [==============================] - 4s 252ms/step - loss: 0.9530 - accuracy: 0.6914 - val_loss: 1.0846 - val_accuracy: 0.6198
# Epoch 18/79
# 16/16 [==============================] - 5s 292ms/step - loss: 0.8777 - accuracy: 0.7221 - val_loss: 1.0306 - val_accuracy: 0.5868
# Epoch 19/79
# 16/16 [==============================] - 6s 401ms/step - loss: 0.9262 - accuracy: 0.7016 - val_loss: 1.0103 - val_accuracy: 0.6364
# Epoch 20/79
# 16/16 [==============================] - 4s 254ms/step - loss: 0.8457 - accuracy: 0.7241 - val_loss: 1.0926 - val_accuracy: 0.6281
# Epoch 21/79
# 16/16 [==============================] - 7s 424ms/step - loss: 0.8176 - accuracy: 0.7260 - val_loss: 0.9608 - val_accuracy: 0.6612
# Epoch 22/79
# 16/16 [==============================] - 4s 253ms/step - loss: 0.8576 - accuracy: 0.7221 - val_loss: 1.0305 - val_accuracy: 0.6446
# Epoch 23/79
# 16/16 [==============================] - 4s 249ms/step - loss: 0.7896 - accuracy: 0.7476 - val_loss: 0.9973 - val_accuracy: 0.6612
# Epoch 24/79
# 16/16 [==============================] - 5s 309ms/step - loss: 0.7527 - accuracy: 0.7652 - val_loss: 0.9387 - val_accuracy: 0.6694
# Epoch 25/79
# 16/16 [==============================] - 4s 250ms/step - loss: 0.7389 - accuracy: 0.7544 - val_loss: 0.9380 - val_accuracy: 0.6529
# Epoch 26/79
# 16/16 [==============================] - 4s 254ms/step - loss: 0.7089 - accuracy: 0.7750 - val_loss: 0.9742 - val_accuracy: 0.6942
# Epoch 27/79
# 16/16 [==============================] - 5s 281ms/step - loss: 0.7222 - accuracy: 0.7417 - val_loss: 0.9373 - val_accuracy: 0.6942
# Epoch 28/79
# 16/16 [==============================] - 4s 266ms/step - loss: 0.6739 - accuracy: 0.7759 - val_loss: 0.9062 - val_accuracy: 0.6777
# Epoch 29/79
# 16/16 [==============================] - 5s 307ms/step - loss: 0.6478 - accuracy: 0.7867 - val_loss: 0.9402 - val_accuracy: 0.6612
# Epoch 30/79
# 16/16 [==============================] - 5s 277ms/step - loss: 0.6652 - accuracy: 0.7896 - val_loss: 0.9370 - val_accuracy: 0.7107
# Epoch 31/79
# 16/16 [==============================] - 4s 242ms/step - loss: 0.6101 - accuracy: 0.7984 - val_loss: 0.9557 - val_accuracy: 0.6942
# Epoch 32/79
# 16/16 [==============================] - 5s 304ms/step - loss: 0.5871 - accuracy: 0.8112 - val_loss: 0.9550 - val_accuracy: 0.6364
# Epoch 33/79
# 16/16 [==============================] - 7s 374ms/step - loss: 0.5713 - accuracy: 0.8160 - val_loss: 0.9423 - val_accuracy: 0.6694
# Epoch 34/79
# 16/16 [==============================] - 4s 249ms/step - loss: 0.5935 - accuracy: 0.8131 - val_loss: 0.9920 - val_accuracy: 0.6777
# Epoch 35/79
# 16/16 [==============================] - 6s 348ms/step - loss: 0.5626 - accuracy: 0.8258 - val_loss: 0.9981 - val_accuracy: 0.7107
# Epoch 36/79
# 16/16 [==============================] - 4s 252ms/step - loss: 0.5282 - accuracy: 0.8258 - val_loss: 0.9536 - val_accuracy: 0.6860
# Epoch 37/79
# 16/16 [==============================] - 4s 239ms/step - loss: 0.5403 - accuracy: 0.8307 - val_loss: 0.9680 - val_accuracy: 0.6777
# Epoch 38/79
# 16/16 [==============================] - 5s 343ms/step - loss: 0.4974 - accuracy: 0.8337 - val_loss: 0.9060 - val_accuracy: 0.7107

# %%
plt.plot(history_vgg16.history['accuracy'])
plt.plot(history_vgg16.history['val_accuracy'])
plt.title('Model Accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(['Train', 'Validation'], loc='upper left')
plt.show()

# %%
accuracy = new_model.evaluate(X_test_normalized, y_test_encoded, verbose=2)
# Out:
# 5/5 - 0s - loss: 0.7869 - accuracy: 0.7481 - 250ms/epoch - 50ms/step

# %%
# Here we would get the output as probablities for each category
y_pred=new_model.predict(X_test_normalized)
# Out:
# 5/5 [==============================] - 0s 39ms/step

# %%
# Obtaining the categorical values from y_test_encoded and y_pred
y_pred_arg=np.argmax(y_pred,axis=1)
y_test_arg=np.argmax(y_test_encoded,axis=1)

# Plotting the Confusion Matrix using confusion matrix() function which is also predefined tensorflow module
confusion_matrix = tf.math.confusion_matrix(y_test_arg,y_pred_arg)
f, ax = plt.subplots(figsize=(10, 8))
sns.heatmap(
    confusion_matrix,
    annot=True,
    linewidths=.4,
    fmt="d",
    square=True,
    ax=ax
)
plt.show()

# %%
print(classification_report(y_test_arg,y_pred_arg))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.81      0.93      0.87        14
#            1       0.82      0.69      0.75        13
#            2       0.71      0.71      0.71        14
#            3       0.87      0.93      0.90        14
#            4       0.65      0.85      0.73        13
#            5       0.83      0.38      0.53        13
#            6       0.61      0.79      0.69        14
#            7       0.69      0.69      0.69        13
#            8       0.82      0.69      0.75        13
#            9       0.79      0.79      0.79        14
#
#     accuracy                           0.75       135
#    macro avg       0.76      0.75      0.74       135
# weighted avg       0.76      0.75      0.74       135

# %% [markdown]
# - According to the confusion matrix and accuracy curve, the VGG16 model has outperformed Model-2.
# - Thus we can say that VGG16 is our best model and we can use this model to predict and visualize some test images.

# %% [markdown]
# ## **Visualizing the prediction:**

# %%
# # Visualizing the predicted and correct label of images from test data
# plt.figure(figsize=(2,2))
# plt.imshow(X_test[2])
# plt.show()
# print('Predicted Label', enc.inverse_transform(new_model.predict((X_test_normalized[2].reshape(1,64,64,3)))))   # reshaping the input image as we are only trying to predict using a single image
# print('True Label', enc.inverse_transform(y_test_encoded)[2])                                               # using inverse_transform() to get the output label from the output vector

# plt.figure(figsize=(2,2))
# plt.imshow(X_test[33])
# plt.show()
# print('Predicted Label', enc.inverse_transform(new_model.predict((X_test_normalized[33].reshape(1,64,64,3)))))  # reshaping the input image as we are only trying to predict using a single image
# print('True Label', enc.inverse_transform(y_test_encoded)[33])                                              # using inverse_transform() to get the output label from the output vector

# plt.figure(figsize=(2,2))
# plt.imshow(X_test[36])
# plt.show()
# print('Predicted Label', enc.inverse_transform(new_model.predict((X_test_normalized[36].reshape(1,64,64,3)))))  # reshaping the input image as we are only trying to predict using a single image
# print('True Label', enc.inverse_transform(y_test_encoded)[36])                                              # using inverse_transform() to get the output label from the output vector

# %%
def imgplotter(imgid,imgsize = 64):
  plt.figure(figsize=(2,2))
  plt.imshow(X_test[imgid])
  plt.show()
  print('Predicted Label', enc.inverse_transform(new_model.predict((X_test_normalized[imgid].reshape(1,imgsize,imgsize,3)))))   # reshaping the input image as we are only trying to predict using a single image
  print('True Label', enc.inverse_transform(y_test_encoded)[imgid])                                               # using inverse_transform() to get the output label from the output vector

# %%
imgplotter(120,imgsize = 128)
# Out:
# 1/1 [==============================] - 0s 28ms/step
# Predicted Label ['pygmy_marmoset']
# True Label pygmy_marmoset

# %%
y_test.iloc[125]
# Out:
# Label    white_headed_capuchin
# Name: 1068, dtype: object

# %%
y_test[y_test['Label']=='pygmy_marmoset']
# Out:
#               Label
# 575  pygmy_marmoset
# 556  pygmy_marmoset
# 599  pygmy_marmoset
# 636  pygmy_marmoset
# 544  pygmy_marmoset
# 541  pygmy_marmoset
# 598  pygmy_marmoset
# 615  pygmy_marmoset
# 617  pygmy_marmoset
# 659  pygmy_marmoset
# 548  pygmy_marmoset
# 640  pygmy_marmoset
# 657  pygmy_marmoset

# %% [markdown]
# ## Conclusion
# - We can observe from the confusion matrix of all the models that our VGG16 model was the best model because it predicted the majority of the classes better than the other models.
# - The test accuracy of the VGG16 model is 63%.
# - Data Augmentation has also helped in improving the model.
# - Simply employing the transfer learning model can produce a better outcome than any ordinary CNN.

# %%
pd.DataFrame({'Models':['Base CNN Model','CNN Model with Data Augmentation','Transfer Learning Model'],'Train Accuracy':['64%','70%','77%'],'Validation Accuracy':['48%','53%','63%'],'Test Accuracy':['51%','62%','63%']})
# Out:
#                              Models Train Accuracy Validation Accuracy  \
# 0                    Base CNN Model            64%                 48%
# 1  CNN Model with Data Augmentation            70%                 53%
# 2           Transfer Learning Model            77%                 63%
#
#   Test Accuracy
# 0           51%
# 1           62%
# 2           63%

# %% [markdown]
# ## Scope of Improvement
# - These models can be further improved by training with different filter sizes and different number of filters.
# - These models can also be trained on the original image_size i.e 128 x 128 rather than being reduced to 64.
# - Data Augmentation can be performed more and dropout_rate can be changed to improve the model performance.
# - Other Transfer Learning architectures can also be used to train the CNN model and these models can be used for classification.
